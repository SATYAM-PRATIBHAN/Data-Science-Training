# %% [markdown]
# # **Loyal Customers**

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Reads the data
df = pd.read_csv("cust_satisfaction.csv")
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
# Provides the information about whole database columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103904 non-null  object
#  1   Customer Type               103904 non-null  object
#  2   Type of Travel              103904 non-null  object
#  3   Class                       103904 non-null  object
#  4   satisfaction                103904 non-null  object
#  5   Age                         103904 non-null  int64
#  6   Flight Distance             103904 non-null  int64
#  7   Inflight entertainment      103904 non-null  int64
#  8   Baggage handling            103904 non-null  int64
#  9   Cleanliness                 103904 non-null  int64
#  10  Departure Delay in Minutes  103904 non-null  int64
#  11  Arrival Delay in Minutes    103594 non-null  float64
# dtypes: float64(1), int64(6), object(5)
# ...

# %%
# Provides the statistical Data
df.describe()
# Out:
#                  Age  Flight Distance  Inflight entertainment  \
# count  103904.000000    103904.000000           103904.000000
# mean       39.379706      1189.448375                3.358158
# std        15.114964       997.147281                1.332991
# min         7.000000        31.000000                0.000000
# 25%        27.000000       414.000000                2.000000
# 50%        40.000000       843.000000                4.000000
# 75%        51.000000      1743.000000                4.000000
# max        85.000000      4983.000000                5.000000
#
#        Baggage handling    Cleanliness  Departure Delay in Minutes  \
# count     103904.000000  103904.000000               103904.000000
# mean           3.631833       3.286351                   14.815618
# std            1.180903       1.312273                   38.230901
# min            1.000000       0.000000                    0.000000
# 25%            3.000000       2.000000                    0.000000
# ...

# %%
# Provides all the null values of every column
df.isnull().sum()
# Out:
# Gender                          0
# Customer Type                   0
# Type of Travel                  0
# Class                           0
# satisfaction                    0
# Age                             0
# Flight Distance                 0
# Inflight entertainment          0
# Baggage handling                0
# Cleanliness                     0
# Departure Delay in Minutes      0
# Arrival Delay in Minutes      310
# dtype: int64

# %%
# Drops every null value
df.dropna(inplace = True)

# %%
# Prints sum of all null values
df.isnull().sum()
# Out:
# Gender                        0
# Customer Type                 0
# Type of Travel                0
# Class                         0
# satisfaction                  0
# Age                           0
# Flight Distance               0
# Inflight entertainment        0
# Baggage handling              0
# Cleanliness                   0
# Departure Delay in Minutes    0
# Arrival Delay in Minutes      0
# dtype: int64

# %%
# Provides number of all duplicated values
df.duplicated().sum()
# Out:
# np.int64(172)

# %%
# Deletes all the duplicate values and provides number of all duplicated values
df.drop_duplicates(inplace = True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Provides unique values
print(df['Customer Type'].unique())
print(df['Age'].unique())
print(df['Gender'].unique())
print(df['Type of Travel'].unique())
print(df['Class'].unique())
print(df['satisfaction'].unique())
print(df['Inflight entertainment'].unique())
print(df['Baggage handling'].unique())
print(df['Cleanliness'].unique())
# Out:
# ['Loyal Customer' 'disloyal Customer']
# [13 25 26 61 47 52 41 20 24 12 53 33 45 38  9 17 43 58 23 57 49 36 22 31
#  15 35 67 37 40 34 39 50 29 54 21 28 27 69 60 48 59 46 30 66 64 44 51 32
#  19 42 16 11 62  8 56 68 55 18 65 72 70 63 10  7 14 80 74 71 85 73 76 77
#  75 79 78]
# ['Male' 'Female']
# ['Personal Travel' 'Business travel']
# ['Eco Plus' 'Business' 'Eco']
# ['neutral or dissatisfied' 'satisfied']
# [5 1 2 3 4 0]
# [4 3 5 1 2]
# [5 1 2 3 4 0]

# %%
# Creates a dictinory of two keys for loyal customers {dt.keys() : Provides keys, dt.values() : Provides values}
dt  = {'Loyal Customer' : 1, 'disloyal Customer' : 0};
df['Customer Type'] = df['Customer Type'].map(dt)

# %%
# Print unique values of Customer Type
df['Customer Type'].unique()
# Out:
# array([1, 0])

# %%
# Creates a dictinory of two keys for Gerders
dtGender  = {'Male' : 1, 'Female' : 0};
df['Gender'] = df['Gender'].map(dtGender)
df['Gender'].unique()
# Out:
# array([1, 0])

# %%
# Creates a dictinory of two keys for type of travel
dtTypeOfTravel  = {'Personal Travel' : 1, 'Business travel' : 0};
df['Type of Travel'] = df['Type of Travel'].map(dtTypeOfTravel)
df['Type of Travel'].unique()
df
# Out:
#         Gender  Customer Type  Type of Travel     Class  \
# 0            1              1               1  Eco Plus
# 1            1              0               0  Business
# 2            0              1               0  Business
# 3            0              1               0  Business
# 4            1              1               0  Business
# ...        ...            ...             ...       ...
# 103899       0              0               0       Eco
# 103900       1              1               0  Business
# 103901       1              0               0  Business
# 103902       0              0               0       Eco
# 103903       1              1               0  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# ...

# %%
drop_tables = ["Class", "satisfaction", "Baggage handling", "Inflight entertainment", "Cleanliness"]
df.drop(columns = drop_tables, inplace = True)
df
# Out:
#         Gender  Customer Type  Type of Travel  Age  Flight Distance  \
# 0            1              1               1   13              460
# 1            1              0               0   25              235
# 2            0              1               0   26             1142
# 3            0              1               0   25              562
# 4            1              1               0   61              214
# ...        ...            ...             ...  ...              ...
# 103899       0              0               0   23              192
# 103900       1              1               0   49             2347
# 103901       1              0               0   30             1995
# 103902       0              0               0   22             1000
# 103903       1              1               0   27             1723
#
#         Departure Delay in Minutes  Arrival Delay in Minutes
# 0                               25                      18.0
# ...

# %%
x = df.drop('Customer Type', axis = 1)
y = df[['Customer Type']]

# %%
print(x)
print(y)
# Out:
#         Gender  Type of Travel  Age  Flight Distance  \
# 0            1               1   13              460
# 1            1               0   25              235
# 2            0               0   26             1142
# 3            0               0   25              562
# 4            1               0   61              214
# ...        ...             ...  ...              ...
# 103899       0               0   23              192
# 103900       1               0   49             2347
# 103901       1               0   30             1995
# 103902       0               0   22             1000
# 103903       1               0   27             1723
#
#         Departure Delay in Minutes  Arrival Delay in Minutes
# 0                               25                      18.0
# 1                                1                       6.0
# 2                                0                       0.0
# 3                               11                       9.0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)
y_test
# Out:
#        Customer Type
# 40794              1
# 28574              1
# 4920               1
# 71169              1
# 67168              1
# ...              ...
# 78398              0
# 47803              1
# 69942              1
# 6464               1
# 49721              1
#
# [20685 rows x 1 columns]

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((82737, 6), (20685, 6), (82737, 1), (20685, 1))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train, y_train) * 100
# Out:
# 27.17096148908582

# %%
lr.score(x_test, y_test) * 100
# Out:
# 26.479120540929724

# %%
pred = lr.predict(x_test)
pred
# Out:
# array([[0.88142141],
#        [0.82945682],
#        [0.83704731],
#        ...,
#        [0.64873191],
#        [0.86594876],
#        [1.11256601]], shape=(20685, 1))

# %%
y_test['pred'] = pred.ravel()
y_test
# Out:
#        Customer Type      pred
# 40794              1  0.881421
# 28574              1  0.829457
# 4920               1  0.837047
# 71169              1  0.838295
# 67168              1  0.833861
# ...              ...       ...
# 78398              0  0.553239
# 47803              1  0.745694
# 69942              1  0.648732
# 6464               1  0.865949
# 49721              1  1.112566
#
# [20685 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error, root_mean_squared_error, mean_absolute_error
print("MSE : ", mean_squared_error(y_test['Customer Type'], y_test['pred']))
print("MAE : ", mean_absolute_error(y_test['Customer Type'], y_test['pred']))
print("RMSE : ", root_mean_squared_error(y_test['Customer Type'], y_test['pred']))
# Out:
# MSE :  0.10819117635597253
# MAE :  0.2614841931489677
# RMSE :  0.3289242714607308

# %%
y_test['pred'] = (y_test['pred']  > 0.5).astype(int)
y_test['Customer Type'] = (y_test['Customer Type']  > 0.5).astype(int)

# %%
from sklearn.metrics import confusion_matrix, f1_score, precision_score, accuracy_score, recall_score
print("Confusion Matrix : ",confusion_matrix(y_test['Customer Type'], y_test['pred']))
print("Precision Score : ",precision_score(y_test['Customer Type'], y_test['pred']))
print("F1 Score : ", f1_score(y_test['Customer Type'], y_test['pred']))
print("Accuracy Score : ", accuracy_score(y_test['Customer Type'], y_test['pred']))
print("Recall Score : ", recall_score(y_test['Customer Type'], y_test['pred']))
# Out:
# Confusion Matrix :  [[  553  3156]
#  [  157 16819]]
# Precision Score :  0.8420025031289111
# F1 Score :  0.9103407214960353
# Accuracy Score :  0.8398356296833455
# Recall Score :  0.9907516493873704

# %%
import matplotlib.pyplot as plt
import seaborn as sns
cm = confusion_matrix(y_test['Customer Type'], y_test['pred'])
cm
# Out:
# array([[  553,  3156],
#        [  157, 16819]])

# %%
sns.heatmap(cm, annot=True, cmap="Reds", fmt='d')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier(criterion = "entropy")
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dtc.score(x_train, y_train) * 100
# Out:
# 98.99319530560692

# %%
dtc.predict(x_test)
# Out:
# array([1, 1, 1, ..., 0, 1, 1], shape=(20685,))

# %%
import os, joblib

# %%
os.makedirs('../Models', exist_ok = True)
joblib.dump(lr, '../Models/linear_loyal_customer_model.pkl')
# Out:
# ['../Models/linear_loyal_customer_model.pkl']
